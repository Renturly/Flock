# %%
#Mixpanel: Export Birds of a Feather for Thursday Fistfuls of Cash: Data Wrangling for Observations - POF Amount for GitHub: Share to Twitter
import numpy as np 
from matplotlib import pyplot as plt 

OKBird = .19
x = np.array([1 * OKBird, 2 * OKBird, 5 * OKBird]) 
y = 142 + 6 * x 
plt.title("Pipeline") 
plt.xlabel("Revenue") 
plt.ylabel("Flock") 
plt.plot(x,y) 
plt.show()

#You can Make $7K with $150: Fill Pandas with Birds of a Feather: pd.read_csv() is Flock
#.drop_duplicates()
#.head()
#.shape
#dictionary
#.rename({}, axis=1)
#.dtypes
#.nunique()
#missingness
#.isna().sum()
#Try to import .csv

import pandas as pd
df2 = pd.DataFrame([
    [1, 'San Diego', 100],
    [2, 'Los Angeles', 120],
],
    columns=[
        'Store ID', 'Location', 'Number of Employees'
    ])

print(df2)

import seaborn as sns

#.to__csv() will save the CSV file in your current directory
#pd.read_csv("../Juno/Birds of a Feather.csv")
# Out:
#    Store ID     Location  Number of Employees
# 0         1    San Diego                  100
# 1         2  Los Angeles                  120
