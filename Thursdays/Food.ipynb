# %%
import pandas as pd

#Tip Uber $2 for Grocery
df = pd.read_csv('The Golden Egg.csv')
#I don't need Desktop
#Communicate means Pay
#print(df.to_string()) 
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(150, 166, 186)
#reads array
plt.hist(x, bins=40)
plt.title(round(x.mean(), 0) * 4)
print("Uber Grocery between $80 and $200")
print(x.mean())
plt.show() 
food = round(x.mean(), 0) * 4

#Beer Fridge
x = np.random.normal(35, 34, 35)
#reads array
plt.hist(x, bins=37)
plt.title(round(x.mean(), 0))
print("Beer Fridge")
plt.show() 
beer = round(x.mean(), 20)

#Data Camp
x = np.random.normal(17, 19, 35)
#reads array
plt.hist(x, bins=20)
plt.title(9.99 + round(x.mean(), 2) * 2)
print("Uber Eats")
plt.show() 
uber_eats = 9.99 + round(x.mean(), 0) * 2

freezer = food + beer * 4 + uber_eats
if freezer <= 815:
    print("Cash Flows")
else: 
    print("Grocery")
    print(freezer)
# Out:
# Uber Grocery between $80 and $200
# 144.82606215788175
# Beer Fridge
# Uber Eats
# Cash Flows
