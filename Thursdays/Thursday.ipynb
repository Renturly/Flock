# %%
import pandas as pd

#Tip Uber $2 for Grocery
print(150 * 4)

df = pd.read_csv('The Golden Egg.csv')
#I don't need Desktop
#Communicate means Pay
print(df.to_string()) 

df.pivot(index='Date', columns='Formula', values='Date')

import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(143, 166, 186)
#reads array
plt.hist(x)
plt.title(round(x.mean(), 2) * 4)
print("Uber Grocery")
plt.show() 
food = round(x.mean(), 2) * 4

#Beer Fridge
x = np.random.normal(35, 34, 35)
#reads array
plt.hist(x)
plt.title(round(x.mean(), 2))
print("Beer Fridge")
plt.show() 
beer = round(x.mean(), 2)

#Data Camp
x = np.random.normal(17, 19, 35)
#reads array
plt.hist(x)
plt.title(9.99 + round(x.mean(), 2) * 2)
print("Uber Eats")
plt.show() 
uber_eats = 9.99 + round(x.mean(), 2) * 2

freezer = food + beer * 4 + uber_eats
if freezer <= 815:
    print("Cash Flows")
else: 
    print("Grocery")
    print(freezer)
# Out:
# 600
#        Date                  Formula  Jul 1 2020, 12:00am - Jul 7 2021, 5:29pm
# 0   2020-07  Bird Dogging Urly Birds                                    0.1714
# 1   2020-08  Bird Dogging Urly Birds                                    0.1333
# 2   2020-09  Bird Dogging Urly Birds                                    0.0370
# 3   2020-10  Bird Dogging Urly Birds                                    0.0513
# 4   2020-11  Bird Dogging Urly Birds                                    0.0909
# 5   2020-12  Bird Dogging Urly Birds                                    0.1034
# 6   2021-01  Bird Dogging Urly Birds                                    0.0800
# 7   2021-02  Bird Dogging Urly Birds                                    0.1111
# 8   2021-03  Bird Dogging Urly Birds                                    0.0588
# 9   2021-04  Bird Dogging Urly Birds                                    0.1111
# 10  2021-05  Bird Dogging Urly Birds                                    0.1429
# 11  2021-06  Bird Dogging Urly Birds                                    0.0833
# 12  2021-07  Bird Dogging Urly Birds                                    1.0000
# Uber Grocery
# Beer Fridge
# Uber Eats
# Cash Flows
