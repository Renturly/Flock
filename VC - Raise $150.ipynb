# %%
#Thursday: Export Mixpanel Birds of a Feather: Consultants for GitHub, Share to Twitter
import numpy as np 
from matplotlib import pyplot as plt 

OKBird = .19
x = np.array([2 * OKBird, 4 * OKBird, 6 * OKBird, 8 * OKBird, 5 * OKBird, 7 * OKBird]) 
y = 142 + 6 * x 
plt.title("Pipeline") 
plt.xlabel("Revenue") 
plt.ylabel("Flock") 
plt.plot(x,y) 
plt.show()

#You can Get $150
